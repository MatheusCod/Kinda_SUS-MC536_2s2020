# %%
import pandas as pd

# !wget https://raw.githubusercontent.com/MatheusCod/Kinda_SUS-MC536_2s2020/main/stage04/CSVs/global_obesity.csv
# Out:
# --2020-11-24 22:45:01--  https://raw.githubusercontent.com/MatheusCod/Kinda_SUS-MC536_2s2020/main/stage04/CSVs/global_obesity.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6039 (5.9K) [text/plain]
# Saving to: ‘global_obesity.csv’
#
# global_obesity.csv  100%[===================>]   5.90K  --.-KB/s    in 0s
#
# 2020-11-24 22:45:02 (80.4 MB/s) - ‘global_obesity.csv’ saved [6039/6039]

# %%
global_obesity=pd.read_csv('global_obesity.csv')

# %%
global_obesity[['BothSexes', 'Interval']] = global_obesity.BothSexes.str.split(" ", expand = True)

# %%
global_obesity.to_csv('treated_global_obesity.csv', index = False)

# %%
# !ls
# Out:
# global_obesity.csv  sample_data  treated_global_obesity.csv

# %%
from google.colab import files
files.download('treated_global_obesity.csv')
